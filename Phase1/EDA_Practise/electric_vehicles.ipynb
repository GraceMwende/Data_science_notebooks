# %% [markdown]
# ### 1a) Loading libraries

# %%
#import pandas library
import pandas as pd
#import matplotlib library
import matplotlib.pyplot as plt
#import seaborn library
import seaborn as sns
# Out:
# c:\Users\Gmwende\anaconda3\envs\learn-env\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# ### b)Reading data for our CSV file

# %%
#lets read the data from the csv file and create a dataftame to be used
df = pd.read_csv('data/Electric_Vehicle_Population_Data.csv')

# %% [markdown]
# ### c)preview the dataset

# %%
#preview first five and last five rows
df
# Out:
#         VIN (1-10)    County            City State  Postal Code  Model Year  \
# 0       WAUTPBFF4H      King         Seattle    WA      98126.0        2017
# 1       WAUUPBFF2J  Thurston         Olympia    WA      98502.0        2018
# 2       5YJSA1E22H  Thurston           Lacey    WA      98516.0        2017
# 3       1C4JJXP62M  Thurston          Tenino    WA      98589.0        2021
# 4       5YJ3E1EC9L    Yakima          Yakima    WA      98902.0        2020
# ...            ...       ...             ...   ...          ...         ...
# 181453  50EA1TEA7P   Douglas  East Wenatchee    WA      98802.0        2023
# 181454  1C4JJXP60N   Spokane  Spokane Valley    WA      99206.0        2022
# 181455  5YJ3E1EA0M      King        Enumclaw    WA      98022.0        2021
# 181456  5YJ3E1EC8L     Clark       Vancouver    WA      98682.0        2020
# 181457  5YJSA1E27F   Whatcom      Bellingham    WA      98225.0        2015
#
# ...

# %% [markdown]
# #### d)Acessing information about our datasets

# %%
#getting to know about our dataset by accessing its information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181458 entries, 0 to 181457
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         181458 non-null  object
#  1   County                                             181455 non-null  object
#  2   City                                               181455 non-null  object
#  3   State                                              181458 non-null  object
#  4   Postal Code                                        181455 non-null  float64
#  5   Model Year                                         181458 non-null  int64
#  6   Make                                               181458 non-null  object
#  7   Model                                              181458 non-null  object
# ...

# %% [markdown]
# ### e)Accessing summary statistics about our data

# %%
#statics for int and float objects
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  181455.000000  181458.000000   181458.000000  181458.000000
# mean    98174.050718    2020.581793       57.826665    1040.236749
# std      2414.241968       2.991140       91.396074    8228.989085
# min      1545.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98122.000000    2022.000000        0.000000       0.000000
# 75%     98370.000000    2023.000000       75.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         181060.000000    1.814580e+05       1.814550e+05
# mean              29.106904    2.214128e+08       5.297575e+10
# std               14.892342    7.528561e+07       1.594876e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
#statics forstr objects
df.describe(include='O').T
# Out:
#                                                     count unique  \
# VIN (1-10)                                         181458  11060
# County                                             181455    193
# City                                               181455    726
# State                                              181458     44
# Make                                               181458     40
# Model                                              181458    143
# Electric Vehicle Type                              181458      2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  181458      3
# Vehicle Location                                   181450    870
# Electric Utility                                   181455     76
#
#                                                                                                  top  \
# VIN (1-10)                                                                                7SAYGDEE6P
# ...

# %% [markdown]
# ### 2.Cleaning our dataset

# %% [markdown]
# ### a)Check column names

# %%
#check our columns
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# ### b)check missing values

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 398
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       3
# ...

# %% [markdown]
# The dataset contains some missing values in the following columns:
#
# - County: 3 missing values
# - City: 3 missing values
# - Postal Code: 3 missing values
# - Legislative District: 398 missing values
# - Vehicle Location: 8 missing values
# - Electric Utility: 3 missing values
# - 2020 Census Tract: 3 missing values
# These missing values are relatively few compared to the total number of records.
#
# However, the high number of missing values in the `Legislative District` column is notable and may require special handling depending on the analysis.

# %%
df['Legislative District'].value_counts(dropna=False,normalize=True)
# Out:
# 41.0    0.064627
# 45.0    0.060273
# 48.0    0.055126
# 1.0     0.043575
# 11.0    0.042770
# 5.0     0.042737
# 36.0    0.041459
# 46.0    0.038604
# 43.0    0.036681
# 37.0    0.029280
# 34.0    0.029004
# 18.0    0.026778
# 44.0    0.026364
# 22.0    0.024860
# 21.0    0.024689
# 32.0    0.024518
# 23.0    0.021504
# 40.0    0.021322
# 26.0    0.019883
# 33.0    0.019652
# 47.0    0.018219
# 31.0    0.017442
# 10.0    0.016996
# 17.0    0.016880
# 39.0    0.014494
# 27.0    0.014064
# 35.0    0.013992
# 42.0    0.013711
# 49.0    0.013491
# 24.0    0.013436
# 28.0    0.012758
# 30.0    0.011854
# 2.0     0.011413
# 25.0    0.010399
# 8.0     0.010228
# 38.0    0.009914
# 6.0     0.009451
# 12.0    0.009302
# 20.0    0.009115
# 4.0     0.008283
# 13.0    0.006938
# 29.0    0.006679
# 14.0    0.006442
# 19.0    0.005913
# 9.0     0.005572
# 16.0    0.004954
# 3.0     0.004943
# 7.0     0.004695
# 15.0    0.002524
# NaN     0.002193
# Name: Legislative District, dtype: float64

# %%
df['Legislative District'].hist()
df['Legislative District'].skew()
# Out:
# -0.4555061600538801

# %% [markdown]
# ### EDA: Detailed Data Analysis
# ### 1.Analysis of Electric Vehicle Adoption Over Time
# understanding trends in EV adoption can indicate how quickly the market is growing and which years saw significant increases

# %%
#set figsize for my whole notebook
sns.set_theme(rc = {'figure.figsize':(12,8)})
sns.countplot(data=df,x='Model Year')
plt.title('Number of Electric Vehicles Registered by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles');

# %%
#matplotlib #tutorial code
plt.figure(figsize=(10, 6))
df['Model Year'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Number of Electric Vehicles Registered by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.grid(axis='y')

# %% [markdown]
# The bar chart shows the number of electric vehicles registered by model year.
#
# There is a noticeable upward trend in EV registrations in the most recent years,indicating growing adoption of electric vehicles over time
#
# The spike of registration in the lates years reflects increase consumer interest and perhaps better availability of EV models

# %% [markdown]
# ### 2.Distribution of Electric vehicles by county
# Geographic distribution provides insigts into whcih areas are adpoting EVs more rapidly
# The bar chart now shows the distribution of elctric vehicles across the top 20 counties in Washington State

# %%
sns.countplot(data=df,x='County',order=df['County'].value_counts().iloc[:20].index)
plt.xticks(rotation=45)
plt.title('Distribution of Electric Vehicles by County (Top 20 Counties)')
plt.xlabel('County')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=90)
plt.grid(axis='y');

# %%
df['County'].value_counts()[:20].plot(kind='bar')
plt.xticks(rotation=45);
plt.title('Distribution of Electric Vehicles by County (Top 20 Counties)')
plt.xlabel('County')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=90)
plt.grid(axis='y')

# %% [markdown]
# This provides a more detailed view of where EV adoption is concentrated, with King County leading by a significant margin, followed by other populous countues such as  Snohomish, Pierce, and Clark.
#
# This visualization highlights the regions with the highest levels of EV adoption, which are typically more Urbarnised areas

# %% [markdown]
# ### 3.Electric range analysis
# The electric range influences user experience and adoption rates.Comparing ranges between BEVs and PHEVs will hihight their differences

# %%
PHEV = df.query('`Electric Vehicle Type` == "Plug-in Hybrid Electric Vehicle (PHEV)"')
BEV = df.query('`Electric Vehicle Type` == "Battery Electric Vehicle (BEV)"')
plt.hist(PHEV['Electric Range'],alpha=0.7,label='PHEV')
plt.hist(BEV['Electric Range'],alpha=0.7,label='BEV')
plt.title('Electric Range Distribution for BEVs and PHEVs')
plt.xlabel('Electric Range (miles)')
plt.ylabel('Number of Vehicles')
plt.legend()
plt.grid(axis='y');

# %% [markdown]
# The histogram compares the electric range distribution between Battery electric vehicles(BEVs) and Plug-in Electri Vehicles(PHEVs)
# - BEVs typically have a wider and higher range with many models achieving range well over 200 miles
# - PHEVs on the other hand have lower electric-only ranges under 50 miles as they also rely on gasoline energy
#
# The differenece reflects the distict roles these two types of vehicles play in the market:BEVs are designed for longer-all electric journeys, while PHEVs provide the flexibility of gasoline negine for extended range

# %% [markdown]
# ### 4.Clean Alternative Fuel Vehicle (CAFV) Eligibility
# The eligibility for clean alternative fuel benefits can impact market trends and consumer preferences.
#
# We will assess the `Clean Alternative Fuel Vehicle (CAFV) Eligibility` to see how many vehicles qualify for these incentives and how this eligibility varies across BEVs and PHEVs.

# %%
clean_fuel_vehicleType = df.pivot_table(index='Electric Vehicle Type',columns='Clean Alternative Fuel Vehicle (CAFV) Eligibility',aggfunc='size')
clean_fuel_vehicleType
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  Clean Alternative Fuel Vehicle Eligible  \
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)                                                     47234.0
# Plug-in Hybrid Electric Vehicle (PHEV)                                             19582.0
#
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  Eligibility unknown as battery range has not been researched  \
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)                                                               94730.0
# Plug-in Hybrid Electric Vehicle (PHEV)                                                           NaN
#
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  Not eligible due to low battery range
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)                                                       9.0
# Plug-in Hybrid Electric Vehicle (PHEV)                                           19903.0

# %%
clean_fuel_vehicleType.plot(kind='bar',stacked=True)
plt.xticks(rotation=0);

# %%
#tutorial code
caf_eligibility = df.groupby(['Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility']).size().unstack()
caf_eligibility_percentage = (caf_eligibility.T / caf_eligibility.T.sum() * 100).T

plt.figure(figsize=(10, 6))

# Using distinct and correctly assigned colors for the stacked bars
caf_eligibility_percentage.plot(kind='bar', stacked=True, color=['#1f77b4', '#2ca02c', '#ff7f0e'])

plt.title('CAFV Eligibility by Electric Vehicle Type')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Percentage of Vehicles')
plt.legend(title='CAFV Eligibility', loc='upper right')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# The stacked bar chart shows the percentage of vehicles that are eligible for Clean Alternative Fuel vehicle(CAFV) incentives across BEVs and PHEVs:
# - BEVs: a significant majority are eligible for CAFV incentives, reflecting theier all-electric nature and alignment with clean energy goals
# - PHEVs: a smaller proportion is eligibel for CAFV incentives, likely due to their lower electric-only range and partial reliance on gasoline

# %% [markdown]
# ### 5.Analysis of Electric Vehicle makes and models
# Popularity trends among EV makes and models can inform market share and consumer preferences

# %%
sns.countplot(data=df, x='Make',order=df['Make'].value_counts().iloc[:20].index)
plt.title('Top 10 Electric Vehicle Makes')
plt.xlabel('Make')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.grid(axis='y');

# %%
sns.countplot(data=df, x='Model',order=df['Model'].value_counts().iloc[:20].index)
plt.title('Top 10 Electric Vehicle Models')
plt.xlabel('Model')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.grid(axis='y');

# %% [markdown]
# ### The bar charts highlight the top 10 most popular elctric vehicles makes and models in washington state:
# - Top makes :Tesla dominates with multiple models contributing to its popularity.Other prominent brands include Nissan,chevlorlet and Toyota
# - Top Models: Tesla models, particularly the Model 3 and Model S, are the most popular, followed by other models like the Nissan Leaf and Chevrolet Volt.
# ![](top5_make_models.PNG)

# %% [markdown]
# ### 6.Legislative districts and Electric vehicle adoption
# This analysis will help us understand how EV adoption varies across different political and administrative regions which may help in infrastracture and policy planning

# %%
sns.countplot(data=df,x='Legislative District',order=df['Legislative District'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Distribution of Electric Vehicles by Legislative District')
plt.xlabel('Legislative District')
plt.ylabel('Number of Vehicles');

# %% [markdown]
# The bar chart shows the distribution of elctric vehicles across diffrenet legislative districts in Washington Sate
#
# Some districts have notably higher concentrations of EVs(eg districts 1, 5, 11, 36, 41, 45 and 48) which could be due to factors like higher urbanisation, better charging infrastracture, or stronger local policies promoting EV adoption

# %% [markdown]
# ### 7.Electric Utilities and Their Role in Supporting EVs
# Analysing the distribution by electric utility helps in understanding the regional infrastracture and potential load on the grid
#
# In other words, this will provide insights into the infrastructure supporting the growing number of EVs.

# %%
sns.countplot(data=df,x='Electric Utility',order=df['Electric Utility'].value_counts().iloc[:10].index)
plt.title('Top 10 Electric Utilities by Number of EVs Served')
plt.xlabel('Electric Utility')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=90)
plt.grid(axis='y');

# %% [markdown]
# The bar chart shows the top 10 electric utilities by the number of electric vehicles they serve in Washington State.
#
# Utilities like Puget Sound Energy and City of Seattle – Seattle City Light are among the largest providers for EVs, which is expected given their service areas include major urban centres with higher EV adoption rates.

# %% [markdown]
# ### 8. Market Share of Top 10 Electric vehicle Makes

# %%
df_count = df['Make'].value_counts().head(10)
plt.pie(df_count,labels=df_count.index,autopct='%1.1f%%');

# %% [markdown]
# Tesla has a dominant share of the market, with nearly half of all registered EVs in the state.
#
# Other manufacturers like Nissan, Chevrolet, and Ford have significantly smaller shares, indicating Tesla’s strong position in the EV market.

# %% [markdown]
# ### 9.Trends in EV Adoption by Make Over Time
# Let’s analyse how the adoption of EVs by these top makes has evolved over the years. This will give us insights into which brands are gaining or losing market share over time.

# %%
ev_trend_by_make = df.groupby(['Model Year','Make']).size().unstack().fillna(0)
top_makes =df['Make'].value_counts().index[:5]
ev_trend_by_top_makes = ev_trend_by_make[top_makes]
ev_trend_by_top_makes.plot(kind='line',marker='o')
plt.title('Trends in EV Adoption by Top 5 Makes Over Time')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles Registered')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend(title='Make');

# %% [markdown]
# The line chart shows the trends in electric vehicle adoption over time for the top 5 makes: Tesla, Nissan, Chevrolet, Ford, and BMW.
#
# This analysis highlights Tesla’s rapid and sustained growth in the EV market, while other brands are growing at a slower pace, with some seeing increased adoption in more recent years.

# %% [markdown]
# ### 10.Market Share of Top Models
# Let’s calculate the market share of these top 10 models relative to the total number of EVs in the dataset. This will give us a clearer picture of their dominance in the market.

# %%
df_count = df['Model'].value_counts().head(10)
plt.pie(df_count,labels=df_count.index,autopct='%1.1f%%');

# %% [markdown]
# Tesla’s dominance is evident, with the Model Y and Model 3 together capturing over 37% of the market.
#
# The Nissan Leaf is the most popular non-Tesla model, followed by the Chevrolet Bolt EV and Tesla’s other models (Model S and Model X).

# %% [markdown]
# ### 11.Trends in EV Adoption by Model Over Time
# Let’s analyse how the adoption of these top models has evolved over the years to understand which models are gaining or losing popularity.
#
# This analysis highlights Tesla’s dominance in the EV market, with their models not only leading in current registrations but also showing strong upward trends over time.

# %%
ev_trend_by_Model = df.groupby(['Model Year','Model']).size().unstack().fillna(0)
top_Models =df['Model'].value_counts().index[:5]
ev_trend_by_top_Models = ev_trend_by_Model[top_Models]
ev_trend_by_top_Models.plot(kind='line',marker='o')
plt.title('Trends in EV Adoption by Top 5 Models Over Time')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles Registered')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend(title='Model');

# %% [markdown]
# The Nissan Leaf, while still popular, has not seen the same level of growth in recent years, reflecting shifts in consumer preferences towards newer models like the Tesla Model Y and Model 3.

# %% [markdown]
# ### 12.Comparison of BEV vs. PHEV Adoption Trends
# Let’s try to understand how the adoption trends of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) compare over time.

# %%
df_count = df['Electric Vehicle Type'].value_counts().head(10)
plt.pie(df_count,labels=df_count.index,autopct='%1.1f%%');

# %% [markdown]
# This analysis will highlight the differences in growth patterns between these two types of electric vehicles.
#
# - Overall Distribution of BEVs and PHEVs
# The pie chart and data show the overall distribution between BEVs and PHEVs in Washington State:
#
# - BEVs: 141,973 vehicles (78.2%)
#
# - PHEVs: 39,485 vehicles (21.8%)
#
# BEVs make up the majority of the electric vehicles, with nearly four times as many BEVs as PHEVs. This reflects a stronger preference for fully electric vehicles compared to hybrids that still rely on gasoline.

# %% [markdown]
# ### Adoption Trends Over Time
# The line chart shows the adoption trends of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) over time:

# %%
ev_trend_by_type = df.groupby(['Model Year','Electric Vehicle Type']).size().unstack().fillna(0)
types=df['Electric Vehicle Type'].value_counts().index
ev_trend_by_top_makes = ev_trend_by_type[types]
ev_trend_by_top_makes.plot(kind='line',marker='o')
# Out:
# <AxesSubplot:xlabel='Model Year'>

# %% [markdown]
# - BEVs: There is a clear upward trend in BEV registrations, with a significant increase in the most recent years. This indicates growing consumer preference for fully electric vehicles.
#
# - PHEVs: While PHEV registrations have also increased over time, the growth is more modest compared to BEVs. PHEVs saw a more gradual rise and have not experienced the same rapid growth as BEVs in recent years.
#
# This comparison highlights the stronger market momentum behind BEVs, likely driven by advancements in battery technology, increased range, and a growing infrastructure for charging fully electric vehicles.

# %% [markdown]
# ### What factors could influence EV adoption rates?
# Electric Vehicle (EV) adoption rates are likely to be influenced by a variety of factors that can be broadly categorised into economic, technological, environmental, policy-driven, and consumer-related factors.
#
# Here’s an overview of these key influences:
#
# ### Economic Factors
# - Purchase Price: The upfront cost of an EV is a significant factor. Although prices have been decreasing, EVs are often more expensive than their internal combustion engine (ICE) counterparts. Government incentives, tax rebates, and subsidies can reduce the effective purchase price and encourage adoption.
# - Total Cost of Ownership (TCO): This includes the long-term costs of owning a vehicle, such as fuel (electricity vs. gasoline), maintenance, and insurance. EVs typically have lower maintenance and fuel costs, which can make them more attractive over time.
# - Resale Value: The expected resale value of an EV also impacts adoption. As the EV market matures and battery technology improves, resale values are expected to stabilize and potentially increase.

# %% [markdown]
# ### Technological Factors
# - Battery Technology and Range: The driving range of EVs on a single charge is a critical factor. Advances in battery technology that increase range and reduce charging times make EVs more practical for everyday use and long trips.
# - Charging Infrastructure: The availability and accessibility of charging stations influence EV adoption. Dense and well-distributed charging networks reduce range anxiety and make EVs more convenient.
# - Vehicle Variety and Performance: The availability of diverse EV models, including different body styles, performance levels, and price points, broadens the appeal to various consumer segments

# %% [markdown]
# ### Environmental and Social Factors
# - Environmental Awareness: Growing awareness of climate change and the environmental benefits of EVs, such as lower emissions, drives consumer interest and adoption.
# - Social Influence and Brand Image: The perception of EVs as innovative and eco-friendly, along with strong brand loyalty (e.g., Tesla), can significantly influence consumer decisions.

# %% [markdown]
# ### Policy and Regulatory Factors
# - Government Incentives: Tax credits, rebates, and incentives (both federal and state) play a significant role in making EVs more affordable and attractive to consumers.
# - Regulations and Emissions Standards: Stricter emissions regulations and the push for zero-emission vehicles by governments can accelerate EV adoption. Some regions also implement bans on the sale of new ICE vehicles by certain dates, further pushing consumers toward EVs.
# - Subsidies for Charging Infrastructure: Government support for the development of charging infrastructure, such as subsidies for installing home chargers or funding public charging stations, is crucial for widespread EV adoption.

# %% [markdown]
# ### Market and Consumer Factors
# - Consumer Awareness and Education: Knowledge about EV benefits, available models, and charging options is crucial. Lack of awareness can be a barrier to adoption.
# - Perceived Barriers: Concerns about battery life, charging times, and the availability of charging infrastructure can deter potential buyers.
# - Urbanisation and Commuting Patterns: Urban areas with shorter average commutes and more charging options tend to have higher EV adoption rates. Rural areas may see slower adoption due to fewer charging stations and longer travel distances.

# %% [markdown]
# ### Energy and Utility Factors
# - Electricity Costs: The cost of electricity relative to gasoline influences the economic appeal of EVs. Regions with cheaper electricity see higher adoption rates.
# - Renewable Energy Integration: The integration of renewable energy sources into the grid can enhance the environmental appeal of EVs, particularly if consumers can charge their vehicles using solar or wind power.

# %% [markdown]
# ### Cultural and Behavioral Factors
# - Cultural Norms: In regions where sustainability and green technology are highly valued, EV adoption is likely to be higher.
# - Lifestyle Fit: EVs may be more appealing to consumers who value technology, innovation, and environmental responsibility. Also, early adopters and tech enthusiasts often drive the initial growth of the EV market.

# %% [markdown]
# ### Conclusion
# As our analysis reveals, electric vehicle adoption in Washington State is on a rapid upward trajectory, driven largely by the increasing popularity of Battery Electric Vehicles (BEVs) and the dominance of leading manufacturers like Tesla.
#
# Factors such as the availability of diverse models, advancements in battery technology, and supportive policies are playing crucial roles in accelerating this shift.
#
# While BEVs are leading the charge with their extended range and full-electric capabilities, Plug-in Hybrid Electric Vehicles (PHEVs) continue to appeal to consumers seeking a balance between electric driving and traditional fuel options.
#
# The data also underscores the growing consumer confidence in EV technology and highlights the importance of continued investment in charging infrastructure and supportive policies to sustain this momentum.
#
# As we look to the future, it’s clear that electric vehicles are not just a trend but a pivotal element in the journey towards a more sustainable and connected world of transportation.
