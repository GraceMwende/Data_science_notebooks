# %% [markdown]
# ### Introduction
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" content covers loading data from a corrupted csv file.
#
# ### Objectives
# You will be able to:
#
# Use pandas to import data from a CSV and and an Excel spreadsheet
#
# ### Loading Files with Summary or Meta Data
# What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.

# %%
import pandas as pd
import numpy as np
np.float = np.float64
df = pd.read_excel('Zipcode_Demos.xlsx') #permission denied if you have opened the file
df
#data is not correctly formatted since the real data is downwards since the data above is average starts
#we have to indicate where the header should start
#Teachers Comment
#Dataframe is really two table views, one on top of the other. 
# The first is a summary view of the raw data below. 
# There is also a blank row at row 1 in the file.
# Out:
#                                       0          Unnamed: 1    Unnamed: 2  \
# 0                    Average Statistics                 NaN           NaN
# 1                                   NaN                   0           NaN
# 2                     JURISDICTION NAME             10005.8           NaN
# 3                    COUNT PARTICIPANTS                 9.4           NaN
# 4                          COUNT FEMALE                 4.8           NaN
# 5                        PERCENT FEMALE               0.404           NaN
# 6                            COUNT MALE                 4.6           NaN
# 7                          PERCENT MALE               0.396           NaN
# 8                  COUNT GENDER UNKNOWN                   0           NaN
# 9                PERCENT GENDER UNKNOWN                   0           NaN
# 10                   COUNT GENDER TOTAL                 9.4           NaN
# 11                 PERCENT GENDER TOTAL                  80           NaN
# ...

# %%
df = pd.read_excel('Zipcode_Demos.xlsx',header=48)
df
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
# 5              10006                   6             2            0.33
# 6              10007                   1             0            0.00
# 7              10009                   2             0            0.00
# 8              10010                   0             0            0.00
# 9              10011                   3             2            0.67
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# ...

# %%
### Teachers code
#import the first part of the data
df1 = pd.read_excel('Zipcode_Demos.xlsx',nrows=46,header=1,usecols=[0,1])
#my code drop row 0
df1.drop(0,inplace=True)
df1.reset_index(inplace=True,drop=True)
df1.head()
# Out:
#    Average Statistics  Unnamed: 1
# 0   JURISDICTION NAME   10005.800
# 1  COUNT PARTICIPANTS       9.400
# 2        COUNT FEMALE       4.800
# 3      PERCENT FEMALE       0.404
# 4          COUNT MALE       4.600

# %%
df1.tail()
# Out:
#                      Average Statistics  Unnamed: 1
# 40    COUNT NRECEIVES PUBLIC ASSISTANCE       7.100
# 41  PERCENT NRECEIVES PUBLIC ASSISTANCE       0.649
# 42      COUNT PUBLIC ASSISTANCE UNKNOWN       0.000
# 43    PERCENT PUBLIC ASSISTANCE UNKNOWN       0.000
# 44        COUNT PUBLIC ASSISTANCE TOTAL       9.400

# %%
# teacher code import table 2
df2 = pd.read_excel('Zipcode_Demos.xlsx',skiprows=48)
df2.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# ...

# %% [markdown]
# ### Level Up (Optional) - Loading Corrupt CSV files
# Occasionally, you encounter some really ill-formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is supposed to use quotes to differentiate between the commas denoting fields and the commas within those fields themselves. For example, we could have a table like this:
#
# ReviewerID,Rating,N_reviews,Review,VenueID 123456,4,137,This restaurant was pretty good, we had a great time.,98765
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text): "ReviewerID","Rating","N_reviews","Review","VenueID" "123456","4","137","This restaurant was pretty good, we had a great time.","98765"
#
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled 'Yelp_Reviews_Corrupt.csv'. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
# my code
try:
    df= pd.read_csv('Yelp_Reviews_Corrupt.csv',on_bad_lines='warn')
except Exception as e:
    print(e)
# Out:
# b'Skipping line 2331: expected 10 fields, saw 11\nSkipping line 2340: expected 10 fields, saw 12\nSkipping line 2341: expected 10 fields, saw 13\nSkipping line 2343: expected 10 fields, saw 18\nSkipping line 2349: expected 10 fields, saw 12\nSkipping line 2350: expected 10 fields, saw 16\nSkipping line 2352: expected 10 fields, saw 12\nSkipping line 2358: expected 10 fields, saw 13\nSkipping line 2359: expected 10 fields, saw 11\nSkipping line 2379: expected 10 fields, saw 11\nSkipping line 2381: expected 10 fields, saw 12\nSkipping line 2382: expected 10 fields, saw 12\nSkipping line 2384: expected 10 fields, saw 11\nSkipping line 2386: expected 10 fields, saw 12\nSkipping line 2388: expected 10 fields, saw 12\nSkipping line 2389: expected 10 fields, saw 13\nSkipping line 2392: expected 10 fields, saw 15\nSkipping line 2393: expected 10 fields, saw 18\nSkipping line 2394: expected 10 fields, saw 15\nSkipping line 2407: expected 10 fields, saw 12\nSkipping line 2427: expected 10 fiel
# ...

# %%
df= pd.read_csv('Yelp_Reviews_Corrupt.csv',on_bad_lines='warn') #use warn or skip
df
# Out:
# b'Skipping line 2331: expected 10 fields, saw 11\nSkipping line 2340: expected 10 fields, saw 12\nSkipping line 2341: expected 10 fields, saw 13\nSkipping line 2343: expected 10 fields, saw 18\nSkipping line 2349: expected 10 fields, saw 12\nSkipping line 2350: expected 10 fields, saw 16\nSkipping line 2352: expected 10 fields, saw 12\nSkipping line 2358: expected 10 fields, saw 13\nSkipping line 2359: expected 10 fields, saw 11\nSkipping line 2379: expected 10 fields, saw 11\nSkipping line 2381: expected 10 fields, saw 12\nSkipping line 2382: expected 10 fields, saw 12\nSkipping line 2384: expected 10 fields, saw 11\nSkipping line 2386: expected 10 fields, saw 12\nSkipping line 2388: expected 10 fields, saw 12\nSkipping line 2389: expected 10 fields, saw 13\nSkipping line 2392: expected 10 fields, saw 15\nSkipping line 2393: expected 10 fields, saw 18\nSkipping line 2394: expected 10 fields, saw 15\nSkipping line 2407: expected 10 fields, saw 12\nSkipping line 2427: expected 10 fiel
# ...

# %%
len(df)
# Out:
# 4035

# %%
### Teachers code
# Your code here
try:
    df = pd.read_csv('Data/Yelp_Reviews_Corrupt.csv')
except Exception as e:
    print(e)
# Out:
# Error tokenizing data. C error: Expected 10 fields in line 2331, saw 11

# %%
# # Iteration 1 
for i in range(1500,2000):
    try:
        df = pd.read_csv('Data/Yelp_Reviews_Corrupt.csv', nrows=i)
    except:
        print(f'First failure at: {i}')
        break
df1 = pd.read_csv('Data/Yelp_Reviews_Corrupt.csv', nrows=i-1)
print(len(df))
df1.head()
# Out:
# First failure at: 1962
# 1961
#   Unnamed: 0             business_id cool        date  funny  \
# 0          1  pomGBqfbxcqPv14c3XH-ZQ    0  2012-11-13    0.0
# 1          2  jtQARsP6P-LbkyjbO1qNGg    1  2014-10-23    1.0
# 2          4  Ums3gaP2qM3W1XcA5r6SsQ    0  2014-09-05    0.0
# 3          5  vgfcTvK81oD4r50NMjU2Ag    0  2011-02-25    0.0
# 4         10  yFumR3CWzpfvTH2FCthvVw    0  2016-06-15    0.0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw    5.0
# 1  LZp4UX5zK3e-c5ZGSeo3kA    1.0
# 2  jsDu6QEJHbwP2Blom1PLCA    5.0
# 3  pfavA0hr3nyqO61oupj-lA    1.0
# 4  STiFMww2z31siPY7BWNC2g    5.0
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...     0.0
# 1  Terrible. Dry corn bread. Rib tips were all fa...     3.0
# 2  Delicious healthy food. The steak is amazing. ...     0.0
# 3  This place sucks. The customer service is horr...     2.0
# ...
